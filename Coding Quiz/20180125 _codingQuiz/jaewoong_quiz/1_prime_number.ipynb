# %%
# %%timeit
# O(n^2) 밖에 안떠오른당
sum = 0

for number in range(2, 1000 + 1):
    div = 0
    for each in range(2, number):
        if number % each == 0:
            div += 1

        if div >= 1 and number != each:
            break

    if div == 0:
        sum += 1

# print(sum)
# Out:
# 6.03 ms ± 50.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
primes = [1]

for each in range(2,1000+1):
    div = 0
    for prime in primes:
        if each % prime == 0:
            div+=1
            
    # 해당 정수가 소수임
    if div==1:
        primes.append(each)
        
result = len(primes) - 1
# Out:
# 4.51 ms ± 41.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# 모든 정수는 약수로 소수를 가진다
# => 어떤 정수의 약수가 소수로 2개 이상 가진다면 그 수는 소수가 아니다

# 1. 
primes = [1]

for each in range(2,1000+1):
    div = 0
    for prime in primes:
        if each % prime == 0:
            div+=1
            
    # 해당 정수가 소수임
    if div==1:
        primes.append(each)
    
# primes.pop(0)
# print(primes)
